# %%
from sklearn.linear_model import LogisticRegression
import pandas as pd
import numpy as np

# %%
X = pd.read_csv("features/datasetv").set_index('session_id')
y = pd.read_csv("features/y_features.csv").set_index('session_id')

# %%
X
# Out:
#               customer_type  session_duration_microseconds  signed_up  \
# session_id
# 1.661517e+09              0                       0.001110          0
# 1.661496e+09              1                       0.011419          1
# 1.661959e+09              0                       0.031012          0
# 1.656311e+09              0                       0.000971          0
# 1.664185e+09              0                       0.000145          0
# ...                     ...                            ...        ...
# 1.649242e+09              0                       0.000000          0
# 1.660141e+09              0                       0.000000          0
# 1.663753e+09              0                       0.000823          0
# 1.663765e+09              0                       0.186182          0
# 1.653514e+09              0                       0.000003          0
#
#               pages_visited  app_removed  personalise_store_pageviews  \
# session_id
# ...

# %%
clf = LogisticRegression(random_state=0).fit(X, y['completed_transaction'])
# Out:
# C:\Users\samukhia\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
y['completed_transaction']
# Out:
#               completed_transaction
# session_id
# 1.661517e+09                      0
# 1.661496e+09                      0
# 1.661959e+09                      0
# 1.656311e+09                      0
# 1.664185e+09                      0
# ...                             ...
# 1.649242e+09                      0
# 1.660141e+09                      0
# 1.663753e+09                      0
# 1.663765e+09                      0
# 1.653514e+09                      0
#
# [1382 rows x 1 columns]
